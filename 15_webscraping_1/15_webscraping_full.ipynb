# %%
! conda install bs4 lxml --yes
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# # WebScraping
# ## 1. Extracting one Row of Data

# %% [markdown]
# ### Reviewing the source
#
# - First we take a look at the page of HTML we want to capture. In a seperate window open up http://www.uberpeople.net/forums/Tips.
#
# - Explore the page as it is rendered in the browser, and the underlying code by right clicking on the page and using 'View Page Source'.
#
# - For now, we're just going to pull this entire page into memory and then we'll work out how to extract the parts we want.
#
#
# To retrieve the HTML we're going to use the Requests library which we will import below.
#
# The documentation for Requests can be found at http://docs.python-requests.org/en/master/

# %%
# Due to website design we will need to present ourselves as a web browser
# Using the file of 'user-agent' data we can send the correct headers when making our requests 
from random import choice
with open('user_agent.txt','r') as f:
    agents = f.readlines()
    agents = [x.strip() for x in agents]

# %%
import requests

# %%
response = requests.get('http://uberpeople.net/forums/Tips/', headers={'user-agent': choice(agents)}) # Yes it is that simple - thanks Requests!

# %%
#  If we look at our html object we get a simple response code. 200 is a success, 404 for example would be a failure.
#  For a full list of Http response codes see https://httpstatuses.com
response
# Out:
# <Response [200]>

# %%
# We can look at the content of the retrieved package. 
# Click the bar to the left of the text to expand or contract its screen usage.
response.text
# Out:
# '<!DOCTYPE html>\n<html id="XF" lang="en-US" dir="LTR"\n\tdata-app="public"\n\tdata-template="forum_view"\n\tdata-container-key="node-16"\n\tdata-content-key=""\n\tdata-logged-in="false"\n\tdata-cookie-prefix="xf_"\n\tclass="has-no-js template-forum_view"\n\t>\n<head>\n<!-- ConsolidatedFooters Headers -->\n\n<!-- Analytics -->\n<script type="text/javascript">\n  var _gaq = _gaq || [];\n  _gaq.push(["_setAccount", "UA-147480215-48"]);\n  _gaq.push(["_setDomainName", ".uberpeople.net"]);\n  _gaq.push (["_gat._anonymizeIp"]);\n  _gaq.push(["_trackPageview"]);\n  (function() {\n    var ga = document.createElement("script"); ga.type = "text/javascript"; ga.async = true;\n    ga.src = ("https:" == document.location.protocol ? "https://ssl" : "http://www") + ".google-analytics.com/ga.js";\n    var s = document.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ga, s);\n  })();\n</script>\n<!-- /Analytics -->\n\n<!-- Comscore --><script type="text/javascript">\nif (typeof googlefc == "object") {\n\tgooglefc.callbackQueue.push(function() {\n\t\tif ( gfchelper.isAdProviderAllowed("comscore") ) {\n\t\t\t \nvar _comscore = _comscore || [];\n_comscore.push({ c1: "2", c2: "6036030", c4: "uberpeople.net" });\n(function() {\nvar s = document.createElement("script"), el =\ndocument.getElementsByTagName("script")[0]; s.async = true;\ns.src = (document.location.protocol == "https:" ? "https://sb" :\n"http://b") + ".scorecardresearch.com/beacon.js";\nel.parentNode.insertBefore(s, el);\n})(); \n\n\t\t};\n\t});\n} else {\n\t \nvar _comscore = _comscore || [];\n_comscore.push({ c1: "2", c2: "6036030", c4: "uberpeople.net" });\n(function() {\nvar s = document.createElement("script"), el =\ndocument.getElementsByTagName("script")[0]; s.async = true;\ns.src = (document.location.protocol == "https:" ? "https://sb" :\n"http://b") + ".scorecardresearch.com/beacon.js";\nel.parentNode.insertBefore(s, el);\n})(); \n\n}\n</script><!-- /Comscore -->\n<!-- /ConsolidatedFooters Headers -->\n\n\t<meta charset="utf-8" />\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n\t<meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover">\n\n\t\n\t\n\t\n\n\t<title>Advice | Uber Drivers Forum</title>\n\n\t\n\t\t<link rel="canonical" href="https://uberpeople.net/forums/Tips/" />\n\t\n\t\t<link rel="alternate" type="application/rss+xml" title="RSS feed for Advice" href="/forums/Tips/index.rss" />\n\t\n\t\t<link rel="next" href="/forums/Tips/page-2" />\n\t\n\n\t\n\t\t\n\t\n\t\n\t<meta property="og:site_name" content="Uber Drivers Forum" />\n\n\n\t\n\t\n\t\t\n\t\n\t\n\t<meta property="og:type" content="website" />\n\n\n\t\n\t\n\t\t\n\t\n\t\n\t\n\t\t<meta property="og:title" content="Advice" />\n\t\t<meta property="twitter:title" content="Advice" />\n\t\n\n\n\t\n\t\n\t\t\n\t\n\t\n\t\n\t\t<meta name="description" content="Driver help, tips, technique, and frequently asked questions." />\n\t\t<meta property="og:description" content="Driver help, tips, technique, and frequently asked questions." />\n\t\t<meta property="twitter:description" content="Driver help, tips, technique, and frequently asked questions." />\n\t\n\n\n\t\n\t\n\t\t\n\t\n\t\n\t<meta property="og:url" content="https://www.uberpeople.net/forums/Tips/" />\n\n\n\t\n\t\n\t\t\n\t\n\t\n\t\n\t\t<meta property="og:image" content="https://uberpeople.net/logo.og.png" />\n\t\t<meta property="twitter:image" content="https://uberpeople.net/logo.og.png" />\n\t\t<meta property="twitter:card" content="summary" />\n\t\n\n\n\t\n\n\t\n\t\t<meta name="theme-color" content="#3c4759" />\n\t\n\n\t\n\t\n\n\t\n\t<link rel="preload" href="https://uberpeople.b-cdn.net/styles/fonts/fa/fa-regular-400.woff2" as="font" type="font/woff2" crossorigin="anonymous" />\n\n\n\t<link rel="preload" href="https://uberpeople.b-cdn.net/styles/fonts/fa/fa-solid-900.woff2" as="font" type="font/woff2" crossorigin="anonymous" />\n\n\n<link rel="preload" href="https://uberpeople.b-cdn.net/styles/fonts/fa/fa-bran ...

# %% [markdown]
# ### Inspecting your source
# - Ok that big block of mess isn't that helpful...
# - We need to find a systematic way of combing through the entire HTML, and picking out what we need.
# - Make sure the page is open in Chrome or Firefox and then right click on the first title and choose 'Inspect (Element)' to see the underlying code.
#
# We can see that each row is in its own division. All these divisions sit inside a parent division with the class `"structItemContainer-group js-threadList"`. Knowing this will let us drill down into each row, and later iterate over each row and perform the same actions. To do this we will use a library called **Beautiful Soup**.
#
# Documentation for Beautiful Soup https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
# First we get Beautiful soup to break down the HTML into something that can be navigated.
from bs4 import BeautifulSoup 

soup = BeautifulSoup(response.text,'lxml') # we have to make sure we give it the html.text content, and define the parser.

# %%
# If we look at our soup it is a little more structured, but lets keep refining....
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="has-no-js template-forum_view" data-app="public" data-container-key="node-16" data-content-key="" data-cookie-prefix="xf_" data-logged-in="false" data-template="forum_view" dir="LTR" id="XF" lang="en-US">
#  <head>
#   <!-- ConsolidatedFooters Headers -->
#   <!-- Analytics -->
#   <script type="text/javascript">
#    var _gaq = _gaq || [];
#   _gaq.push(["_setAccount", "UA-147480215-48"]);
#   _gaq.push(["_setDomainName", ".uberpeople.net"]);
#   _gaq.push (["_gat._anonymizeIp"]);
#   _gaq.push(["_trackPageview"]);
#   (function() {
#     var ga = document.createElement("script"); ga.type = "text/javascript"; ga.async = true;
#     ga.src = ("https:" == document.location.protocol ? "https://ssl" : "http://www") + ".google-analytics.com/ga.js";
#     var s = document.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ga, s);
#   })();
#   </script>
#   <!-- /Analytics -->
#   <!-- Comscore -->
#   <script type="text/javascript">
#    if (typeof googlefc == "object") {
# 	googlefc.callbackQueue.push(function() {
# 		if ( gfchelper.isAdProviderAllowed("comscore") ) {
#
# var _comscore = _comscore || [];
# _comscore.push({ c1: "2", c2: "6036030", c4: "uberpeople.net" });
# (function() {
# var s = document.createElement("script"), el =
# document.getElementsByTagName("script")[0]; s.async = true;
# s.src = (document.location.protocol == "https:" ? "https://sb" :
# "http://b") + ".scorecardresearch.com/beacon.js";
# el.parentNode.insertBefore(s, el);
# })();
#
# 		};
# 	});
# } else {
#
# var _comscore = _comscore || [];
# _comscore.push({ c1: "2", c2: "6036030", c4: "uberpeople.net" });
# (function() {
# var s = document.createElement("script"), el =
# document.getElementsByTagName("script")[0]; s.async = true;
# s.src = (document.location.protocol == "https:" ? "https://sb" :
# "http://b") + ".scorecardresearch.com/beacon.js";
# el.parentNode.insertBefore(s, el);
# })();
#
# }
#   </script>
#   <!-- /Comscore -->
#   <!-- /ConsolidatedFooters Headers -->
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"/>
#   <title>
#    Advice | Uber Drivers Forum
#   </title>
#   <link href="https://uberpeople.net/forums/Tips/" rel="canonical"/>
#   <link href="/forums/Tips/index.rss" rel="alternate" title="RSS feed for Advice" type="application/rss+xml"/>
#   <link href="/forums/Tips/page-2" rel="next"/>
#   <meta content="Uber Drivers Forum" property="og:site_name"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Advice" property="og:title"/>
#   <meta content="Advice" property="twitter:title"/>
#   <meta content="Driver help, tips, technique, and frequently asked questions." name="description"/>
#   <meta content="Driver help, tips, technique, and frequently asked questions." property="og:description"/>
#   <meta content="Driver help, tips, technique, and frequently asked questions." property="twitter:description"/>
#   <meta content="https://www.uberpeople.net/forums/Tips/" property="og:url"/>
#   <meta content="https://uberpeople.net/logo.og.png" property="og:image"/>
#   <meta content="https://uberpeople.net/logo.og.png" property="twitter:image"/>
#   <meta content="summary" property="twitter:card"/>
#   <meta content="#3c4759" name="theme-color"/>
#   <link as="font" crossorigin="anonymous" href="https://uberpeople.b-cdn.net/styles/fonts/fa/fa-regular-400.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="https://uberpeople.b-cdn.net/styles/fonts/fa/fa-solid-900.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="https://uberpeople.b-cdn.net/styles/fonts/fa/fa-brands-400.woff2" rel="preload" type="font/woff2"/>
#   <link href="/css.php?css=public%3Anormalize.css%2Cpublic%3Afa.css%2Cpublic%3Acore.less%2Cpublic%3Aapp.less&amp;s=9&amp;l=1&amp;d=1612991744&amp;k=0498bd062013113462c62fc4f66e2dfbf6f83adf" rel="stylesheet"/>
#   <link href="/css.php?css=public%3Anode_list.less%2Cpublic%3Anotices.less%2Cpublic%3Asiropu_ads_manager_ad.less%2Cpublic%3Astructured_list.less%2Cpublic%3Aextra.less&amp;s=9&amp;l=1&amp;d=1612991744&amp;k=212c9a05271e5cc28185a8d38d77bb493ef6f94c" rel="stylesheet"/>
#   <script src="https://www.uberpeople.net/js/xf/preamble.min.js?_v=39471467">
#   </script>
#   <link href="https://uberpeople.net/logo.og.png" rel="apple-touch-icon"/>
#   <script type="text/javascript">
#    // Initialize the deployads array, for asynchronous use
#     window.deployads = window.deployads || [];
#
#     // Load Sortable's library
#     wrapperSrc = "//tags-cdn.deployads.com/a/vs.uberpeople.net.js";
#
#     (function() {
#         var gads = document.createElement('script');
#         gads.async = true;
#         gads.type = 'text/javascript';
#         var useSSL = 'https:' == document.location.protocol;
#         gads.src = (useSSL ? 'https:' : 'http:') + wrapperSrc;
#         var node = document.getElementsByTagName('script')[0];
#         node.parentNode.insertBefore(gads, node);
#     })();
#   </script>
#   <!-- GPT async boilerplate -->
#   <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js">
#   </script>
#   <script>
#    var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#   </script>
#   <!-- /GPT async boilerplate -->
#   <!-- GPT Config -->
#   <script type="text/javascript">
#    googletag.cmd.push(function() {
#         //Size Mapping
#         var desktop728x90Mapping = googletag.sizeMapping()
#         .addSize([320, 400], [])
#         .addSize([320, 700], [])
#         .addSize([480, 200], [])
#         .addSize([768, 200], [728, 90])
#         .addSize([1024, 200], [728, 90])
#         .build();
#
#         var desktop300x250Mapping = googletag.sizeMapping()
#         .addSize([320, 400], [])
#         .addSize([320, 700], [])
#         .addSize([480, 200], [])
#         .addSize([768, 200], [300, 250])
#         .addSize([1024, 200], [300, 250])
#         .build();
#
#         var mobile320x50Mapping = googletag.sizeMapping()
#         .addSize([320, 400], [320, 50])
#         .addSize([320, 700], [320, 50])
#         .addSize([480, 200], [320, 50])
#         .addSize([768, 200], [])
#         .addSize([1024, 200], [])
#         .build();
#
#         var mobile300x250Mapping = googletag.sizeMapping()
#         .addSize([320, 400], [300, 250])
#         .addSize([320, 700], [300, 250])
#         .addSize([480, 200], [300, 250])
#         .addSize([768, 200], [])
#         .addSize([1024, 200], [])
#         .build();
#         //Size Mapping end
#
#         //Forum Ad Units
#         googletag.defineSlot('/1030735/UberPeople_net_728x90_Top_AUTO_Forum', [728, 90], 'UberPeople_net_728x90_Top_AUTO_Forum').defineSizeMapping(desktop728x90Mapping).addService(googletag.pubads());
#         googletag.defineSlot('/1030735/UberPeople_net_300x250_BottomLeft_AUTO_Forum', [300, 250], 'UberPeople_net_300x250_BottomLeft_AUTO_Forum').defineSizeMapping(desktop300x250Mapping).addService(googletag.pubads());
#         googletag.defineSlot('/1030735/UberPeople_net_300x250_BottomRight_AUTO_Forum', [300, 250], 'UberPeople_net_300x250_BottomRight_AUTO_Forum').defineSizeMapping(desktop300x250Mapping).addService(googletag.pubads());
#         var hideBottomBanner = getCookie("hideBottomBanner");
#         if (hideBottomBanner == "") {
#             googletag.defineSlot('/1030735/UberPeople_net_728x90_Bottom_AUTO_Forum', [728, 90], 'UberPeople_net_728x90_Bottom_AUTO_Forum').defineSizeMapping(desktop728x90Mapping).addService(googletag.pubads());
#         }
#         var hideTopBanner = getCookie("hideTopBanner");
#         if (hideTopBanner == "") {
#             googletag.defineSlot('/1030735/UberPeople_net_320x50_Top_AUTO_Forum', [320, 50], 'UberPeople_net_320x50_Top_AUTO_Forum').defineSizeMapping(mobile320x50Mapping).addService(googletag.pubads());
#         }
#         googletag.defineSlot('/1030735/UberPeople_net_300x250_TopMobile_AUTO_Forum', [300, 250], 'UberPeople_net_300x250_TopMobile_AUTO_Forum').defineSizeMapping(mobile300x250Mapping).addService(googletag.pubads());
#         googletag.defineSlot('/1030735/UberPeople_net_300x250_BottomMobile_AUTO_Forum', [300, 250], 'UberPeople_net_300x250_BottomMobile_AUTO_Forum').defineSizeMapping(mobile300x250Mapping).addService(googletag.pubads());
#
#
#             googletag.defineSlot('/1030735/UberPeople_net_300x250_TopRight_AUTO_Forum', [300, 250], 'UberPeople_net_300x250_TopRight_AUTO_Forum').defineSizeMapping(desktop300x250Mapping).addService(googletag.pubads());
#             googletag.defineSlot('/1030735/UberPeople_net_728x90_After10thThread_AUTO_Forum', [728, 90], 'UberPeople_net_728x90_After10thThread_AUTO_Forum').defineSizeMapping(desktop728x90Mapping).addService(googletag.pubads());
#             googletag.defineSlot('/1030735/UberPeople_net_300x250_After10thThreadMobile_AUTO_Forum', [300, 250], 'UberPeople_net_300x250_After10thThreadMobile_AUTO_Forum').defineSizeMapping(mobile300x250Mapping).addService(googletag.pubads());
#             googletag.defineSlot('/1030735/UberPeople_net_300x250_AfterThreadMobile_AUTO_Forum', [300, 250], 'UberPeople_net_300x250_AfterThreadMobile_AUTO_Forum').defineSizeMapping(mobile300x250Mapping).addService(googletag.pubads());
#
#
#         //Forum Ad Units end
#
#         //Custom Targeting
#
#         googletag.pubads().setTargeting("registered", "false");
#
#         googletag.pubads().setTargeting("sitename", "UberPeople.net");
#         googletag.pubads().setTargeting("forum_id", "16");
#         //Custom Targeting end
#         googletag.pubads().enableLazyLoad({fetchMarginPercent:50,renderMarginPercent:75,mobileScaling:1});
#         googletag.pubads().enableSingleRequest();
#         if (window.deployads) {
#         deployads.push(function () { deployads.gpt.enableServices() });
#         } else {
#             googletag.enableServices();
#         }
#         });
#   </script>
#   <!-- /GPT Config -->
#   <script>
#    function getCookie(cname) {
#     var name = cname + "=";
#     var ca = document.cookie.split(';');
#     for(var i = 0; i < ca.length; i++) {
#         var c = ca[i];
#         while (c.charAt(0) == ' ') {
#         c = c.substring(1);
#         }
#         if (c.indexOf(name) == 0) {
#         return c.substring(name.length, c.length);
#         }
#     }
#     return "";
#     }
#     function checkTopCookie() {
#         var hideTopBanner = getCookie("hideTopBanner");
#         if (hideTopBanner != "") {
#             document.getElementById("closeTopBanner").style.display = "none";
#         } else {
#             if (window.deployads) {
#             deployads.push(function() {
#                 deployads.gpt.display('UberPeople_net_320x50_Top_AUTO_Forum');
#                 });
#             } else {
#                 googletag.display('UberPeople_net_320x50_Top_AUTO_Forum');
#             }
#         }
#     }
#     function checkBottomCookie() {
#         var hideBottomBanner = getCookie("hideBottomBanner");
#         if (hideBottomBanner != "") {
#             document.getElementById("closeBottomBanner").style.display = "none";
#         } else {
#             if (window.deployads) {
#             deployads.push(function() {
#                 deployads.gpt.display('UberPeople_net_728x90_Bottom_AUTO_Forum');
#                 });
#             } else {
#                 googletag.display('UberPeople_net_728x90_Bottom_AUTO_Forum');
#             }
#         }
#     }
#   </script>
#  </head>
#  <body data-template="forum_view">
#   <div class="p-pageWrapper" id="top">
#    <header class="p-header" id="header">
#     <div class="p-header-inner">
#      <div class="p-header-content">
#       <div class="p-header-logo p-header-logo--image">
#        <a href="/">
#         <img alt="Uber Drivers Forum" src="https://uberpeople.net/uberdriverforum.png"/>
#        </a>
#       </div>
#       <div class="samCodeUnit" data-position="container_header">
#        <div class="samItem" data-cc="true" data-cv="true" data-id="64" data-xf-init="sam-item">
#         <div class="AdvallyTag" data-autosize="leaderboard" data-slot="/1093718/UBERPEOPLE/UP_HEAD_LB" id="UP_HEAD_LB">
#         </div>
#         <div id="UberPeople_net_728x90_Top_AUTO_Forum">
#          <script type="text/javascript">
#           googletag.cmd.push(function() {
# 		if (window.deployads) {
# 		deployads.push(function() {
# 			deployads.gpt.display('UberPeople_net_728x90_Top_AUTO_Forum');
# 			});
# 		} else {
# 			googletag.display('UberPeople_net_728x90_Top_AUTO_Forum');
# 		}
# 		});
#          </script>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#    <div class="p-navSticky p-navSticky--primary" data-xf-init="sticky-header">
#     <nav class="p-nav">
#      <div class="p-nav-inner">
#       <a class="p-nav-menuTrigger" data-menu=".js-headerOffCanvasMenu" data-xf-click="off-canvas" role="button" tabindex="0">
#        <i aria-hidden="true">
#        </i>
#        <span class="p-nav-menuText">
#         Menu
#        </span>
#       </a>
#       <div class="p-nav-smallLogo">
#        <a class="sc_logoSmall" href="/">
#         <img alt="Uber Drivers Forum" src="https://uberpeople.net/driverforummobile.png"/>
#        </a>
#       </div>
#       <div class="p-nav-scroller hScroller" data-auto-scroll=".p-navEl.is-selected" data-xf-init="h-scroller">
#        <div class="hScroller-scroll">
#         <ul class="p-nav-list js-offCanvasNavSource">
#          <li>
#           <div class="p-navEl" data-has-children="true">
#            <a class="p-navEl-link p-navEl-link--splitMenu" data-nav-id="EWRporta" href="/ewr-porta/">
#             Home
#            </a>
#            <a aria-expanded="false" aria-haspopup="true" aria-label="Toggle expanded" class="p-navEl-splitTrigger" data-menu-pos-ref="&lt; .p-navEl" data-xf-click="menu" data-xf-key="1" role="button" tabindex="0">
#            </a>
#            <div aria-hidden="true" class="menu menu--structural" data-menu="menu">
#             <div class="menu-content">
#              <!--<h4 class="menu-header">Home</h4>-->
#              <a class="menu-linkRow u-indentDepth0 js-offCanvasCopy" data-nav-id="EWRporta_whatsnaw" href="/whats-new/">
#               What's new
#              </a>
#              <a class="menu-linkRow u-indentDepth0 js-offCanvasCopy" data-nav-id="Articles" href="https://uberpeople.net/forums/Articles/">
#               Articles
#              </a>
#              <a class="menu-linkRow u-indentDepth0 js-offCanvasCopy" data-nav-id="EWRporta_authors" href="/ewr-porta/authors/">
#               Authors
#              </a>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li>
#           <div class
#              </a>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li>
#           <div class="p-navEl" data-has-children="true">
#            <a class="p-navEl-link p-navEl-link--splitMenu" data-nav-id="whatsNew" href="/whats-new/">
#             What's new
#            </a>
#            <a aria-expanded="false" aria-haspopup="true" aria-label="Toggle expanded" class="p-navEl-splitTrigger" data-menu-pos-ref="&lt; .p-navEl" data-xf-click="menu" data-xf-key="6" role="button" tabindex="0">
#            </a>
#            <div aria-hidden="true" class="menu menu--structural" data-menu="menu">
#             <div class="menu-content">
#              <!--<h4 class="menu-header">What's new</h4>-->
#              <a class="menu-linkRow u-indentDepth0 js-offCanvasCopy" data-nav-id="whatsNewPosts" href="/whats-new/posts/" rel="nofollow">
#               New posts
#              </a>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li>
#           <div class="p-navEl" data-has-children="true">
#            <a aria-expanded="false" aria-haspopup="true" class="p-navEl-linkHolder" data-menu-pos-ref="&lt; .p-navEl" data-xf-click="menu" data-xf-key="7" role="button" tabindex="0">
#             <span class="p-navEl-link p-navEl-link--menuTrigger" data-nav-id="Tools">
#              Tools
#             </span>
#            </a>
#            <div aria-hidden="true" class="menu menu--structural" data-menu="menu">
#             <div class="menu-content">
#              <!--<h4 class="menu-header">Tools</h4>-->
#              <a class="menu-linkRow u-indentDepth0 js-offCanvasCopy" data-nav-id="searchForums" href="/search/?type=post">
#               Search forums
#              </a>
#              <a class="menu-linkRow u-indentDepth0 js-offCanvasCopy" data-nav-id="Resources" href="https://uberpeople.net/categories/resources.23/">
#               Resources
#              </a>
#             </div>
#            </div>
#           </div>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="p-nav-opposite">
#        <div class="p-navgroup p-account p-navgroup--guest">
#         <a class="p-navgroup-link p-navgroup-link--textual p-navgroup-link--logIn" data-follow-redirects="on" data-xf-click="overlay" href="/login/">
#          <span class="p-navgroup-linkText">
#           Log in
#          </span>
#         </a>
#         <a class="p-navgroup-link p-navgroup-link--textual p-navgroup-link--register" data-follow-redirects="on" data-xf-click="overlay" href="/register/">
#          <span class="p-navgroup-linkText">
#           Register
#          </span>
#         </a>
#        </div>
#        <div class="p-navgroup p-discovery">
#         <a class="p-navgroup-link p-navgroup-link--iconic p-navgroup-link--whatsnew" href="/whats-new/" title="What's new">
#          <i aria-hidden="true">
#          </i>
#          <span class="p-navgroup-linkText">
#           What's new
#          </span>
#         </a>
# ...
# 			deployads.gpt.display('UberPeople_net_300x250_BottomMobile_AUTO_Forum');
# 			});
# 		} else {
# 			googletag.display('UberPeople_net_300x250_BottomMobile_AUTO_Forum');
# 		}
# 		});
#          </script>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <footer class="p-footer" id="footer">
#     <div class="p-footer-inner">
#      <div class="samCodeUnit" data-position="footer">
#       <div class="samItem">
#        <script>
#         var advally = advally || {};
# advally.cmd = advally.cmd || [];
# advally.cmd.push(function() {
#   advally.Sidehesion.show()
# });
#        </script>
#       </div>
#      </div>
#      <div class="p-footer-row">
#       <div class="p-footer-row-main">
#        <ul class="p-footer-linkList">
#         <li>
#          <a data-xf-click="overlay" data-xf-init="tooltip" href="/misc/style" rel="nofollow" title="Style chooser">
#           <i aria-hidden="true" class="fa--xf far fa-paint-brush">
#           </i>
#           Daily Driver
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="p-footer-row-opposite">
#        <ul class="p-footer-linkList">
#         <li>
#          <a data-xf-click="overlay" href="/misc/contact">
#           Contact us
#          </a>
#         </li>
#         <li>
#          <a href="/help/">
#           Help
#          </a>
#         </li>
#         <li>
#          <a class="p-footer-rssLink" href="/forums/-/index.rss" target="_blank" title="RSS">
#           <span aria-hidden="true">
#            <i aria-hidden="true" class="fa--xf far fa-rss">
#            </i>
#            <span class="u-srOnly">
#             RSS
#            </span>
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="p-footer-copyright">
#       <a class="u-concealed" dir="ltr" href="https://xenforo.com" rel="sponsored noopener" target="_blank">
#        Forum software by XenForo
#        <sup>
#         ®
#        </sup>
#        <span class="copyright">
#         © 2010-2020 XenForo Ltd.
#        </span>
#       </a>
#       UberPeople.NET is in no way affiliated with Uber (Rasier-CA LLC).
#       <div class="porta-copyright">
#        <a href="https://xenforo.com/community/resources/6023/" target="_blank">
#         XenPorta 2 PRO
#        </a>
#        © Jason Axelrod of
#        <a href="https://8wayrun.com/" target="_blank">
#         8WAYRUN
#        </a>
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <!-- closing p-pageWrapper -->
#   <div class="u-bottomFixer js-bottomFixTarget">
#    <ul class="notices notices--floating js-notices" data-scroll-interval="6" data-type="floating" data-xf-init="notices">
#     <li class="notice js-notice customNotice" data-auto-dismiss="" data-delay-duration="0" data-display-duration="0" data-notice-id="1" data-visibility="">
#      <div class="notice-content">
#       <b>
#        <a href="http://bit.ly/2SKjhqv">
#         Click HERE to join our community of thousands of drivers from around the world, it's FREE!
#        </a>
#       </b>
#      </div>
#     </li>
#    </ul>
#   </div>
#   <div class="u-scrollButtons js-scrollButtons" data-trigger-type="up">
#    <a class="button--scroll button" data-xf-click="scroll-to" href="#top">
#     <span class="button-text">
#      <i aria-hidden="true" class="fa--xf far fa-arrow-up">
#      </i>
#      <span class="u-srOnly">
#       Top
#      </span>
#     </span>
#    </a>
#   </div>
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.5.1/jquery.min.js">
#   </script>
#   <script>
#    window.jQuery || document.write('<script src="https://www.uberpeople.net/js/vendor/jquery/jquery-3.5.1.min.js?_v=39471467"><\/script>')
#   </script>
#   <script src="https://www.uberpeople.net/js/vendor/vendor-compiled.js?_v=39471467">
#   </script>
#   <script src="https://www.uberpeople.net/js/xf/core-compiled.js?_v=39471467">
#   </script>
#   <script>
#    XF.samViewCountMethod = "view";
# 	XF.samServerTime = 1614264245;
# 	XF.samItem = ".samItem";
# 	XF.samCodeUnit = ".samCodeUnit";
# 	XF.samBannerUnit = ".samBannerUnit";
#   </script>
#   <script src="https://www.uberpeople.net/js/siropu/am/core.min.js?_v=39471467">
#   </script>
#   <script src="https://www.uberpeople.net/js/xf/notice.min.js?_v=39471467">
#   </script>
#   <script>
#    jQuery.extend(true, XF.config, {
# 			//
# 			userId: 0,
# 			enablePush: true,
# 			pushAppServerKey: 'BD8XXdcaXrmezYu5JVcZXi/Ln2cbC66dgOmorqBDAzZg2ogUnButI9ZLK6J5ntJJpt4oizfmHBLRJEVnsJ04hFU=',
# 			url: {
# 				fullBase: 'https://www.uberpeople.net/',
# 				basePath: '/',
# 				css: '/css.php?css=__SENTINEL__&s=9&l=1&d=1612991744',
# 				keepAlive: '/login/keep-alive'
# 			},
# 			cookie: {
# 				path: '/',
# 				domain: '',
# 				prefix: 'xf_',
# 				secure: true
# 			},
# 			cacheKey: '852d7736f7e2728b620aa90e477e09f6',
# 			csrf: '1614264245,0cd9ad92dd9bb2eaee098e70f9cd568f',
# 			js: {"https:\/\/www.uberpeople.net\/js\/siropu\/am\/core.min.js?_v=39471467":true,"https:\/\/www.uberpeople.net\/js\/xf\/notice.min.js?_v=39471467":true},
# 			css: {"public:node_list.less":true,"public:notices.less":true,"public:siropu_ads_manager_ad.less":true,"public:structured_list.less":true,"public:extra.less":true},
# 			time: {
# 				now: 1614264245,
# 				today: 1614240000,
# 				todayDow: 4,
# 				tomorrow: 1614326400,
# 				yesterday: 1614153600,
# 				week: 1613721600
# 			},
# 			borderSizeFeature: '3px',
# 			fontAwesomeWeight: 'r',
# 			enableRtnProtect: true,
# 			enableFormSubmitSticky: true,
# 			uploadMaxFilesize: 16777216,
# 			allowedVideoExtensions: ["m4v","mov","mp4","mp4v","mpeg","mpg","ogv","webm"],
# 			allowedAudioExtensions: ["mp3","ogg","wav"],
# 			shortcodeToEmoji: true,
# 			visitorCounts: {
# 				conversations_unread: '0',
# 				alerts_unviewed: '0',
# 				total_unread: '0',
# 				title_count: true,
# 				icon_indicator: true
# 			},
# 			jsState: {},
# 			publicMetadataLogoUrl: 'https://uberpeople.net/logo.og.png',
# 			publicPushBadgeUrl: 'https://www.uberpeople.net/styles/default/xenforo/bell.png'
# 		});
#
# 		jQuery.extend(XF.phrases, {
# 			//
# 			date_x_at_time_y: "{date} at {time}",
# 			day_x_at_time_y:  "{day} at {time}",
# 			yesterday_at_x:   "Yesterday at {time}",
# 			x_minutes_ago:    "{minutes} minutes ago",
# 			one_minute_ago:   "1 minute ago",
# 			a_moment_ago:     "A moment ago",
# 			today_at_x:       "Today at {time}",
# 			in_a_moment:      "In a moment",
# 			in_a_minute:      "In a minute",
# 			in_x_minutes:     "In {minutes} minutes",
# 			later_today_at_x: "Later today at {time}",
# 			tomorrow_at_x:    "Tomorrow at {time}",
#
# 			day0: "Sunday",
# 			day1: "Monday",
# 			day2: "Tuesday",
# 			day3: "Wednesday",
# 			day4: "Thursday",
# 			day5: "Friday",
# 			day6: "Saturday",
#
# 			dayShort0: "Sun",
# 			dayShort1: "Mon",
# 			dayShort2: "Tue",
# 			dayShort3: "Wed",
# 			dayShort4: "Thu",
# 			dayShort5: "Fri",
# 			dayShort6: "Sat",
#
# 			month0: "January",
# 			month1: "February",
# 			month2: "March",
# 			month3: "April",
# 			month4: "May",
# 			month5: "June",
# 			month6: "July",
# 			month7: "August",
# 			month8: "September",
# 			month9: "October",
# 			month10: "November",
# 			month11: "December",
#
# 			active_user_changed_reload_page: "The active user has changed. Reload the page for the latest version.",
# 			server_did_not_respond_in_time_try_again: "The server did not respond in time. Please try again.",
# 			oops_we_ran_into_some_problems: "Oops! We ran into some problems.",
# 			oops_we_ran_into_some_problems_more_details_console: "Oops! We ran into some problems. Please try again later. More error details may be in the browser console.",
# 			file_too_large_to_upload: "The file is too large to be uploaded.",
# 			uploaded_file_is_too_large_for_server_to_process: "The uploaded file is too large for the server to process.",
# 			files_being_uploaded_are_you_sure: "Files are still being uploaded. Are you sure you want to submit this form?",
# 			attach: "Attach files",
# 			rich_text_box: "Rich text box",
# 			close: "Close",
# 			link_copied_to_clipboard: "Link copied to clipboard.",
# 			text_copied_to_clipboard: "Text copied to clipboard.",
# 			loading: "Loading…",
#
# 			processing: "Processing",
# 			'processing...': "Processing…",
#
# 			showing_x_of_y_items: "Showing {count} of {total} items",
# 			showing_all_items: "Showing all items",
# 			no_items_to_display: "No items to display",
#
# 			number_button_up: "Increase",
# 			number_button_down: "Decrease",
#
# 			push_enable_notification_title: "Push notifications enabled successfully at Uber Drivers Forum",
# 			push_enable_notification_body: "Thank you for enabling push notifications!"
# 		});
#   </script>
#   <form hidden="hidden" style="display:none">
#    <input id="_xfClientLoadTime" name="_xfClientLoadTime" tabindex="-1" title="_xfClientLoadTime" type="text" value=""/>
#   </form>
#   <script id="xfReactTooltipTemplate" type="text/template">
#    <div class="tooltip-content-inner">
# 			<div class="reactTooltip">
#
# 					<a href="#" class="reaction reaction--1" data-reaction-id="1"><i aria-hidden="true"></i><img src="..." class="reaction-sprite js-reaction" alt="Like" title="Like" data-xf-init="tooltip" data-extra-class="tooltip--basic tooltip--noninteractive" /></a>
#
# 					<a href="#" class="reaction reaction--3" data-reaction-id="3"><i aria-hidden="true"></i><img src="..." class="reaction-sprite js-reaction" alt="Funny" title="Funny" data-xf-init="tooltip" data-extra-class="tooltip--basic tooltip--noninteractive" /></a>
#
# 					<a href="#" class="reaction reaction--4" data-reaction-id="4"><i aria-hidden="true"></i><img src="..." class="reaction-sprite js-reaction" alt="Wow" title="Wow" data-xf-init="tooltip" data-extra-class="tooltip--basic tooltip--noninteractive" /></a>
#
# 					<a href="#" class="reaction reaction--2" data-reaction-id="2"><i aria-hidden="true"></i><img src="..." class="reaction-sprite js-reaction" alt="Love" title="Love" data-xf-init="tooltip" data-extra-class="tooltip--basic tooltip--noninteractive" /></a>
#
# 			</div>
# 		</div>
#   </script>
#   <script src="https://s.skimresources.com/js/130832X1650703.skimlinks.js" type="text/javascript">
#   </script>
#   <!-- ConsolidatedFooters Footers -->
#   <!-- Adblock Check -->
#   <div class="afs_ads">
#   </div>
#   <script>
#    (function() {
#     var adBlockDetector = function() {
#         setTimeout(function() {
#             if (!document.getElementsByClassName) return;
#
#             var ads = document.getElementsByClassName("afs_ads");
#             ad  = ads[ads.length - 1];
#
#             if (!ad || ad.innerHTML.length == 0 || ad.clientHeight === 0) {
#                 _gaq.push(["_trackEvent", "Adblock", "Blocked", "true",,true]);
#             } else {
#                 ad.style.display = "none";
#                 _gaq.push(["_trackEvent", "Adblock", "Unblocked", "false",,true]);
#             }
#
#         }, 500);
#     }
#
#     /* Attach a listener for page load */
#     if (window.addEventListener) {
#         window.addEventListener("load", adBlockDetector, false);
#     } else {
#         window.attachEvent("onload", adBlockDetector); //IE
#     }
# })();
#   </script>
#   <!-- /Adblock Check-->
#   <!-- TOS DMCA -->
#   <style>
#    .tos_dmca_policy { text-align: center; }
# .tos_dmca_policy table { display: inline-table; width: auto; }
# .tos_dmca_policy table { display: inline-table; width: auto; margin: 0 10px; }
#   </style>
#   <div class="tfoot tos_dmca_policy">
#    <table align="center" border="0" cellpadding="3" cellspacing="0" class="page" width="100%">
#     <tr>
#      <td align="center" class="tfoot" width="100%">
#       <div class="smallfont">
#        <strong>
#         <a href="http://www.verticalscope.com/aboutus/tos.php?site=uberpeople.net" rel="nofollow">
#          Terms of Use
#         </a>
#        </strong>
#       </div>
#      </td>
#     </tr>
#    </table>
#    <!-- DMCA -->
#    <table align="center" border="0" cellpadding="3" cellspacing="0" class="page" width="100%">
#     <tr>
#      <td align="center" class="tfoot" width="100%">
#       <div class="smallfont">
#        <strong>
#         <a href="http://www.verticalscope.com/copyright.html?site=uberpeople.net" rel="nofollow">
#          Copyright
#         </a>
#        </strong>
#       </div>
#      </td>
#     </tr>
#    </table>
#    <!-- /DMCA -->
#    <!-- Privacy Policy -->
#    <table align="center" border="0" cellpadding="3" cellspacing="0" class="page" width="100%">
#     <tr>
#      <td align="center" class="tfoot" width="100%">
#       <div class="smallfont">
#        <strong>
#         <a href="https://www.verticalscope.com/site-privacy-policy/index.php?site=uberpeople.net" rel="nofollow">
#          Privacy Policy
#         </a>
#        </strong>
#       </div>
#      </td>
#     </tr>
#    </table>
#    <!-- /Privacy Policy -->
#    <!-- CCPA LINK -->
#    <table align="center" border="0" cellpadding="3" cellspacing="0" class="qc-ccpa-persistent-link" style="display: none;" width="100%">
#     <tr>
#      <td align="center" class="tfoot" width="100%">
#       <div class="smallfont">
#        <strong>
#         <a style="cursor: pointer;">
#          Do Not Sell My Data
#         </a>
#        </strong>
#       </div>
#      </td>
#     </tr>
#    </table>
#    <!-- /CCPA LINK -->
#    <!-- GDPR LINK -->
#    <table align="center" border="0" cellpadding="3" cellspacing="0" class="qc-cmp-persistent-link" style="display: none;" width="100%">
#     <tr>
#      <td align="center" class="tfoot" width="100%">
#       <div class="smallfont">
#        <strong>
#         <a style="cursor: pointer;">
#          Manage Consent
#         </a>
#        </strong>
#       </div>
#      </td>
#     </tr>
#    </table>
#    <!-- /GDPR LINK -->
#   </div>
#   <!-- /TOS DMCA -->
#   <!-- UK legal cookies -->
#   <style>
#    .uk-cookie-popup {display:none;border: 2px solid #333; background: #f4f4f4; color: #333; Font-size: 11px; padding: 0px 10px 10px; line-height: normal; position: fixed; z-index: 1000001; bottom: 0px; left: 0px; width: 300px; max-width: 100%; margin: 2px; text-align: left; font-family: Arial;}
# .uk-cookie-popup-title {margin: 0px -10px 10px; background: #333; color: #fff; padding: 5px 10px; font-weight: bold;}
# .uk-cookie-popup a {color: #0983b6;}
# .uk-cookie-popup a.uk-cookie-popup-close {float: right; color: #fff; font-size: 14px; display: inline-block; border: 1px solid #ccc; padding: 1px; line-height: 12px }
#   </style>
#   <div class="uk-cookie-popup" id="ukCookiePopup">
#    <div class="uk-cookie-popup-title">
#     <span id="nointelliTXT">
#      <a class="uk-cookie-popup-close" href="" onclick="setUkLegalCookie();return false;">
#       x
#      </a>
#      Cookie and Data Use Consent
#     </span>
#    </div>
#    <span id="nointelliTXT">
#     We use cookies to improve your experience on this website and so that ads you see online can be tailored to your online browsing interests. We use data about you for a number of purposes explained in the links below.  By continuing to browse our site you agree to our use of data and cookies.
#     <br/>
#     <a href="http://www.verticalscope.com/about-us/Data-Use-Consent-Notice.html?site=uberpeople.net" rel="norewrite">
#      Tell me more
#     </a>
#     |
#     <a href="http://www.verticalscope.com/about-us/cookie-preferences.html?site=uberpeople.net" rel="norewrite">
#      Cookie Preferences
#     </a>
#    </span>
#   </div>
#   <script>
#    function createCookie(name,value,days) {
#     if (days) {
#         var date = new Date();
#         date.setTime(date.getTime()+(days*24*60*60*1000));
#         var expires = "; expires="+date.toGMTString();
#     }
#     else var expires = "";
#
#     document.cookie = name+"="+value+expires+"; path=/";
# }
#
# function readCookie(name) {
#     var nameEQ = name + "=";
#     var ca = document.cookie.split(";");
#     for(var i=0;i < ca.length;i++) {
#         var c = ca[i];
#         while (c.charAt(0)==" ") c = c.substring(1,c.length);
#         if (c.indexOf(nameEQ) == 0) return c.substring(nameEQ.length,c.length);
#     }
#     return null;
# }
#
# function eraseCookie(name) {
#     createCookie(name,"",-1);
# }
#
# //Check if cookie has been set
# if (readCookie("uk-cookie-legal") == null) {
#     //show popup
#     document.getElementById("ukCookiePopup").style.display = "block";
# }
#
# function setUkLegalCookie(){
#     createCookie("uk-cookie-legal","been-shown",3650); //set cookie for 10 years
#     document.getElementById("ukCookiePopup").style.display = "none";
# }
#   </script>
#   <!-- END UK legal cookies -->
#   <!-- /ConsolidatedFooters Footers -->
#  </body>
# </html>

# %%
# Let's first focus in on the section of page we want - the division containing all the thread entries
threads_container = soup.find('div', {'class':"structItemContainer-group js-threadList"})
threads_container
# Out:
# <div class="structItemContainer-group js-threadList">
# <div class="structItem structItem--thread js-inlineModContainer js-threadListItem-432355" data-author="akwunomy">
# <div class="structItem-cell structItem-cell--icon">
# <div class="structItem-iconContainer">
# <a class="avatar avatar--s avatar--default avatar--default--dynamic" data-user-id="193430" data-xf-init="member-tooltip" href="/members/akwunomy.193430/" style="background-color: #666699; color: #d1d1e0">
# <span class="avatar-u193430-s">A</span>
# </a>
# </div>
# </div>
# <div class="structItem-cell structItem-cell--main" data-xf-init="touch-proxy">
# <div class="structItem-title">
# <a class="" data-preview-url="/threads/how-did-you-get-your-ppp-loan-forgiven.432355/preview" data-tp-primary="on" data-xf-init="preview-tooltip" href="/threads/how-did-you-get-your-ppp-loan-forgiven.432355/">How did you get your PPP loan forgiven</a>
# </div>
# <div class="structItem-minor">
# <ul class="structItem-parts">
# <li><a class="username" data-user-id="193430" data-xf-init="member-tooltip" dir="auto" href="/members/akwunomy.193430/" itemprop="name">akwunomy</a></li>
# <li class="structItem-startDate"><a href="/threads/how-did-you-get-your-ppp-loan-forgiven.432355/" rel="nofollow"><time class="u-dt" data-date-string="Feb 25, 2021" data-time="1614261190" data-time-string="5:53 AM" datetime="2021-02-25T05:53:10-0800" dir="auto" title="Feb 25, 2021 at 5:53 AM">50 minutes ago</time></a></li>
# </ul>
# </div>
# </div>
# <div class="structItem-cell structItem-cell--meta" title="First message reaction score: 0">
# <dl class="pairs pairs--justified">
# <dt>Replies</dt>
# <dd>1</dd>
# </dl>
# <dl class="pairs pairs--justified structItem-minor">
# <dt>Views</dt>
# <dd>17</dd>
# </dl>
# </div>
# <div class="structItem-cell structItem-cell--latest">
# <a href="/threads/how-did-you-get-your-ppp-loan-forgiven.432355/latest" rel="nofollow"><time class="structItem-latestDate u-dt" data-date-string="Feb 25, 2021" data-time="1614263790" data-time-string="6:36 AM" datetime="2021-02-25T06:36:30-0800" dir="auto" title="Feb 25, 2021 at 6:36 AM">7 minutes ago</time></a>
# <div class="structItem-minor">
# <a class="username" data-user-id="125928" data-xf-init="member-tooltip" dir="auto" href="/members/father-of-unicorns.125928/" itemprop="name">father of unicorns</a>
# </div>
# </div>
# <div class="structItem-cell structItem-cell--icon structItem-cell--iconEnd">
# <div class="structItem-iconContainer">
# <a class="avatar avatar--xxs" data-user-id="125928" data-xf-init="member-tooltip" href="/members/father-of-unicorns.125928/">
# <img alt="father of unicorns" class="avatar-u125928-s" height="48" loading="lazy" src="https://www.uberpeople.net/data/avatars/s
latest" rel="nofollow"><time class="structItem-latestDate u-dt" data-date-string="Feb 24, 2021" data-time="1614211419" data-time-string="4:03 PM" datetime="2021-02-24T16:03:39-0800" dir="auto" title="Feb 24, 2021 at 4:03 PM">Yesterday at 4:03 PM</time></a>
# <div class="structItem-minor">
# <a class="username" data-user-id="204044" data-xf-init="member-tooltip" dir="auto" href="/members/kilroy4303.204044/" itemprop="name">Kilroy4303</a>
# </div>
# </div>
# <div class="structItem-cell structItem-cell--icon structItem-cell--iconEnd">
# <div class="structItem-iconContainer">
# <a class="avatar avatar--xxs" data-user-id="204044" data-xf-init="member-tooltip" href="/members/kilroy4303.204044/">
# <img alt="Kilroy4303" class="avatar-u204044-s" height="48" loading="lazy" src="https://www.uberpeople.net/data/avatars/s/204/204044.jpg?1598651520" width="48"/>
# </a>
# </div>
# </div>
# </div>
# <div class="structItem structItem--thread js-inlineModContainer js-threadListItem-431549" data-author="Kilroy4303">
# <div class="structItem-cell structItem-cell--icon">
# <div class="structItem-iconContainer">
# <a class="avatar avatar--s" data-user-id="204044" data-xf-init="member-tooltip" href="/members/kilroy4303.204044/">
# <img alt="Kilroy4303" class="avatar-u204044-s" height="48" loading="lazy" src="https://www.uberpeople.net/data/avatars/s/204/204044.jpg?1598651520" srcset="https://www.uberpeople.net/data/avatars/m/204/204044.jpg?1598651520 2x" width="48"/>
# </a>
# </div>
# </div>
# <div class="structItem-cell structItem-cell--main" data-xf-init="touch-proxy">
# <div class="structItem-title">
# <a class="" data-preview-url="/threads/tip-or-no-tip.431549/preview" data-tp-primary="on" data-xf-init="preview-tooltip" href="/threads/tip-or-no-tip.431549/">Tip Or No Tip.</a>
# </div>
# <div class="structItem-minor">
# <ul class="structItem-parts">
# <li><a class="username" data-user-id="204044" data-xf-init="member-tooltip" dir="auto" href="/members/kilroy4303.204044/" itemprop="name">Kilroy4303</a></li>
# <li class="structItem-startDate"><a href="/threads/tip-or-no-tip.431549/" rel="nofollow"><time class="u-dt" data-date-string="Feb 19, 2021" data-time="1613765101" data-time-string="12:05 PM" datetime="2021-02-19T12:05:01-0800" dir="auto" title="Feb 19, 2021 at 12:05 PM">Friday at 12:05 PM</time></a></li>
# </ul>
# <span class="structItem-pageJump">
# <a href="/threads/tip-or-no-tip.431549/page-2">2</a>
# </span>
# </div>
# </div>
# <div class="structItem-cell structItem-cell--meta" title="First message reaction score: 0">
# <dl class="pairs pairs--justified">
# <dt>Replies</dt>
# <dd>25</dd>
# </dl>
# <dl class="pairs pairs--justified structItem-minor">
# <dt>Views</dt>
# <dd>358</dd>
# </dl>
# </div>
# <div class="structItem-cell structItem-cell--latest">
# <a href="/threads/tip-or-no-tip.431549/latest" rel="nofollow"><time class="structItem-latestDate u-dt" data-date-string="Feb 24, 2021" data-time="1614211196" data-time-string="3:59 PM" datetime="2021-02-24T15:59:56-0800" dir="auto" title="Feb 24, 2021 at 3:59 PM">Yesterday at 3:59 PM</time></a>
# <div class="structItem-minor">
# <a class="username" data-user-id="204044" data-xf-init="member-tooltip" dir="auto" href="/members/kilroy4303.204044/" itemprop="name">Kilroy4303</a>
# </div>
# </div>
# <div class="structItem-cell structItem-cell--icon structItem-cell--iconEnd">
# <div class="structItem-iconContainer">
# <a class="avatar avatar--xxs" data-user-id="204044" data-xf-init="member-tooltip" href="/members/kilroy4303.204044/">
# <img alt="Kilroy4303" class="avatar-u204044-s" height="48" loading="lazy" src="https://www.uberpeople.net/data/avatars/s/204/204044.jpg?1598651520" width="48"/>
# </a>
# </div>
# </div>
# </div>
# <div class="structItem structItem--thread samUnitWrapper">
# <div class="samCodeUnit" data-position="thread_list_below_item_container_10"><div class="samItem" data-cc="true" data-cl="3" data-cv="true" data-id="59" data-xf-init="sam-item sam-monitor"><div class="AdvallyTag" data-autosize="superleadermpu" data-slot="/1093718/UBERPEOPLE/UP_INL_LB5" id="UP_INL_LB5"></div><div id="UberPeople_net_728x90_After10thThread_AUTO_Forum"><script type="text/javascript">googletag.cmd.push(function() {
# 		if (window.deployads) {
# 		deployads.push(function() {
# 			deployads.gpt.display('UberPeople_net_728x90_After10thThread_AUTO_Forum');
# 			});
# 		} else {
# 			googletag.display('UberPeople_net_728x90_After10thThread_AUTO_Forum');
# 		}
# 		});</script></div><div id="UberPeople_net_300x250_After10thThreadMobile_AUTO_Forum"><script type="text/javascript">googletag.cmd.push(function() {
# 		if (window.deployads) {
# 		deployads.push(function() {
# 			deployads.gpt.display('UberPeople_net_300x250_After10thThreadMobile_AUTO_Forum');
# 			});
# 		} else {
# 			googletag.display('UberPeople_net_300x250_After10thThreadMobile_AUTO_Forum');
# 		}
# 		});</script></div></div></div>
# </div>
# <div class="structItem structItem--thread js-inlineModContainer js-threadListItem-432237" data-author="uberlyftnewbie">
# <div class="structItem-cell structItem-cell--icon">
# <div class="structItem-iconContainer">
# <a class="avatar avatar--s avatar--default avatar--default--dynamic" data-user-id="167671" data-xf-init="member-tooltip" href="/members/uberlyftnewbie.167671/" style="background-color: #ebadad; color: #b82e2e">
# <span class="avatar-u167671-s">U</span>
# </a>
# </div>
# </div>
# <div class="structItem-cell structItem-cell--main" data-xf-init="touch-proxy">
# <div class="structItem-title">
# <a class="" data-preview-url="/threads
time></a>
# <div class="structItem-minor">
# <a class="username" data-user-id="166496" data-xf-init="member-tooltip" dir="auto" href="/members/tomtheant.166496/" itemprop="name">TomTheAnt</a>
# </div>
# </div>
# <div class="structItem-cell structItem-cell--icon structItem-cell--iconEnd">
# <div class="structItem-iconContainer">
# <a class="avatar avatar--xxs" data-user-id="166496" data-xf-init="member-tooltip" href="/members/tomtheant.166496/">
# <img alt="TomTheAnt" class="avatar-u166496-s" height="48" loading="lazy" src="https://www.uberpeople.net/data/avatars/s/166/166496.jpg?1549487294" width="48"/>
# </a>
# </div>
# </div>
# </div>
# <div class="structItem structItem--thread js-inlineModContainer js-threadListItem-431117" data-author="#1husler">
# <div class="structItem-cell structItem-cell--icon">
# <div class="structItem-iconContainer">
# <a class="avatar avatar--s" data-user-id="120256" data-xf-init="member-tooltip" href="/members/1husler.120256/">
# <img alt="#1husler" class="avatar-u120256-s" height="48" loading="lazy" src="https://www.uberpeople.net/data/avatars/s/120/120256.jpg?1503991618" srcset="https://www.uberpeople.net/data/avatars/m/120/120256.jpg?1503991618 2x" width="48"/>
# </a>
# </div>
# </div>
# <div class="structItem-cell structItem-cell--main" data-xf-init="touch-proxy">
# <div class="structItem-title">
# <a class="" data-preview-url="/threads/do-you-let-pax-vape-in-your-car.431117/preview" data-tp-primary="on" data-xf-init="preview-tooltip" href="/threads/do-you-let-pax-vape-in-your-car.431117/">Do you let pax vape in your car?</a>
# </div>
# <div class="structItem-minor">
# <ul class="structItem-parts">
# <li><a class="username" data-user-id="120256" data-xf-init="member-tooltip" dir="auto" href="/members/1husler.120256/" itemprop="name">#1husler</a></li>
# <li class="structItem-startDate"><a href="/threads/do-you-let-pax-vape-in-your-car.431117/" rel="nofollow"><time class="u-dt" data-date-string="Feb 16, 2021" data-time="1613513966" data-time-string="2:19 PM" datetime="2021-02-16T14:19:26-0800" dir="auto" title="Feb 16, 2021 at 2:19 PM">Feb 16, 2021</time></a></li>
# </ul>
# <span class="structItem-pageJump">
# <a href="/threads/do-you-let-pax-vape-in-your-car.431117/page-2">2</a>
# <a href="/threads/do-you-let-pax-vape-in-your-car.431117/page-3">3</a>
# </span>
# </div>
# </div>
# <div class="structItem-cell structItem-cell--meta" title="First message reaction score: 1">
# <dl class="pairs pairs--justified">
# <dt>Replies</dt>
# <dd>54</dd>
# </dl>
# <dl class="pairs pairs--justified structItem-minor">
# <dt>Views</dt>
# <dd>960</dd>
# </dl>
# </div>
# <div class="structItem-cell structItem-cell--latest">
# <a href="/threads/do-you-let-pax-vape-in-your-car.431117/latest" rel="nofollow"><time class="structItem-latestDate u-dt" data-date-string="Feb 21, 2021" data-time="1613940102" data-time-string="12:41 PM" datetime="2021-02-21T12:41:42-0800" dir="auto" title="Feb 21, 2021 at 12:41 PM">Sunday at 12:41 PM</time></a>
# <div class="structItem-minor">
# <a class="username" data-user-id="56908" data-xf-init="member-tooltip" dir="auto" href="/members/derbundes.56908/" itemprop="name">DerBundes</a>
# </div>
# </div>
# <div class="structItem-cell structItem-cell--icon structItem-cell--iconEnd">
# <div class="structItem-iconContainer">
# <a class="avatar avatar--xxs" data-user-id="56908" data-xf-init="member-tooltip" href="/members/derbundes.56908/">
# <img alt="DerBundes" class="avatar-u56908-s" height="48" loading="lazy" src="https://www.uberpeople.net/data/avatars/s/56/56908.jpg?1463420804" width="48"/>
# </a>
# </div>
# </div>
# </div>
# </div>

# %%
# if we take our thread_frame we can use 'find_all' to return a list of child elements that match our criteria.
# Each row has multiple classes, we will just pass the one that seems specific to rows of the table.

threads = threads_container.find_all('div',{'class':'structItem--thread','data-author':True})
threads
# Out:
# [<div class="structItem structItem--thread js-inlineModContainer js-threadListItem-432355" data-author="akwunomy">
#  <div class="structItem-cell structItem-cell--icon">
#  <div class="structItem-iconContainer">
#  <a class="avatar avatar--s avatar--default avatar--default--dynamic" data-user-id="193430" data-xf-init="member-tooltip" href="/members/akwunomy.193430/" style="background-color: #666699; color: #d1d1e0">
#  <span class="avatar-u193430-s">A</span>
#  </a>
#  </div>
#  </div>
#  <div class="structItem-cell structItem-cell--main" data-xf-init="touch-proxy">
#  <div class="structItem-title">
#  <a class="" data-preview-url="/threads/how-did-you-get-your-ppp-loan-forgiven.432355/preview" data-tp-primary="on" data-xf-init="preview-tooltip" href="/threads
>
#  </div>
#  </div>
#  <div class="structItem-cell structItem-cell--icon structItem-cell--iconEnd">
#  <div class="structItem-iconContainer">
#  <a class="avatar avatar--xxs" data-user-id="166496" data-xf-init="member-tooltip" href="/members/tomtheant.166496/">
#  <img alt="TomTheAnt" class="avatar-u166496-s" height="48" loading="lazy" src="https://www.uberpeople.net/data/avatars/s/166/166496.jpg?1549487294" width="48"/>
#  </a>
#  </div>
#  </div>
#  </div>,
#  <div class="structItem structItem--thread js-inlineModContainer js-threadListItem-431117" data-author="#1husler">
#  <div class="structItem-cell structItem-cell--icon">
#  <div class="structItem-iconContainer">
#  <a class="avatar avatar--s" data-user-id="120256" data-xf-init="member-tooltip" href="/members/1husler.120256/">
#  <img alt="#1husler" class="avatar-u120256-s" height="48" loading="lazy" src="https://www.uberpeople.net/data/avatars/s/120/120256.jpg?1503991618" srcset="https://www.uberpeople.net/data/avatars/m/120/120256.jpg?1503991618 2x" width="48"/>
#  </a>
#  </div>
#  </div>
#  <div class="structItem-cell structItem-cell--main" data-xf-init="touch-proxy">
#  <div class="structItem-title">
#  <a class="" data-preview-url="/threads/do-you-let-pax-vape-in-your-car.431117/preview" data-tp-primary="on" data-xf-init="preview-tooltip" href="/threads/do-you-let-pax-vape-in-your-car.431117/">Do you let pax vape in your car?</a>
#  </div>
#  <div class="structItem-minor">
#  <ul class="structItem-parts">
#  <li><a class="username" data-user-id="120256" data-xf-init="member-tooltip" dir="auto" href="/members/1husler.120256/" itemprop="name">#1husler</a></li>
#  <li class="structItem-startDate"><a href="/threads/do-you-let-pax-vape-in-your-car.431117/" rel="nofollow"><time class="u-dt" data-date-string="Feb 16, 2021" data-time="1613513966" data-time-string="2:19 PM" datetime="2021-02-16T14:19:26-0800" dir="auto" title="Feb 16, 2021 at 2:19 PM">Feb 16, 2021</time></a></li>
#  </ul>
#  <span class="structItem-pageJump">
#  <a href="/threads/do-you-let-pax-vape-in-your-car.431117/page-2">2</a>
#  <a href="/threads/do-you-let-pax-vape-in-your-car.431117/page-3">3</a>
#  </span>
#  </div>
#  </div>
#  <div class="structItem-cell structItem-cell--meta" title="First message reaction score: 1">
#  <dl class="pairs pairs--justified">
#  <dt>Replies</dt>
#  <dd>54</dd>
#  </dl>
#  <dl class="pairs pairs--justified structItem-minor">
#  <dt>Views</dt>
#  <dd>960</dd>
#  </dl>
#  </div>
#  <div class="structItem-cell structItem-cell--latest">
#  <a href="/threads/do-you-let-pax-vape-in-your-car.431117/latest" rel="nofollow"><time class="structItem-latestDate u-dt" data-date-string="Feb 21, 2021" data-time="1613940102" data-time-string="12:41 PM" datetime="2021-02-21T12:41:42-0800" dir="auto" title="Feb 21, 2021 at 12:41 PM">Sunday at 12:41 PM</time></a>
#  <div class="structItem-minor">
#  <a class="username" data-user-id="56908" data-xf-init="member-tooltip" dir="auto" href="/members/derbundes.56908/" itemprop="name">DerBundes</a>
#  </div>
#  </div>
#  <div class="structItem-cell structItem-cell--icon structItem-cell--iconEnd">
#  <div class="structItem-iconContainer">
#  <a class="avatar avatar--xxs" data-user-id="56908" data-xf-init="member-tooltip" href="/members/derbundes.56908/">
#  <img alt="DerBundes" class="avatar-u56908-s" height="48" loading="lazy" src="https://www.uberpeople.net/data/avatars/s/56/56908.jpg?1463420804" width="48"/>
#  </a>
#  </div>
#  </div>
#  </div>]

# %%
# We can check this has worked and not given us any more than  the rows by counting the number of rows on the page 
# (20) and checking against the length (len) of the list here...
len(threads)
# Out:
# 20

# %%
# Now let's find that first list item i.e. the first row.
first_item = threads[0]

print(first_item.prettify())
# Out:
# <div class="structItem structItem--thread js-inlineModContainer js-threadListItem-432355" data-author="akwunomy">
#  <div class="structItem-cell structItem-cell--icon">
#   <div class="structItem-iconContainer">
#    <a class="avatar avatar--s avatar--default avatar--default--dynamic" data-user-id="193430" data-xf-init="member-tooltip" href="/members/akwunomy.193430/" style="background-color: #666699; color: #d1d1e0">
#     <span class="avatar-u193430-s">
#      A
#     </span>
#    </a>
#   </div>
#  </div>
#  <div class="structItem-cell structItem-cell--main" data-xf-init="touch-proxy">
#   <div class="structItem-title">
#    <a class="" data-preview-url="/threads/how-did-you-get-your-ppp-loan-forgiven.432355/preview" data-tp-primary="on" data-xf-init="preview-tooltip" href="/threads/how-did-you-get-your-ppp-loan-forgiven.432355/">
#     How did you get your PPP loan forgiven
#    </a>
#   </div>
#   <div class="structItem-minor">
#    <ul class="structItem-parts">
#     <li>
#      <a class="username" data-user-id="193430" data-xf-init="member-tooltip" dir="auto" href="/members/akwunomy.193430/" itemprop="name">
#       akwunomy
#      </a>
#     </li>
#     <li class="structItem-startDate">
#      <a href="/threads/how-did-you-get-your-ppp-loan-forgiven.432355/" rel="nofollow">
#       <time class="u-dt" data-date-string="Feb 25, 2021" data-time="1614261190" data-time-string="5:53 AM" datetime="2021-02-25T05:53:10-0800" dir="auto" title="Feb 25, 2021 at 5:53 AM">
#        50 minutes ago
#       </time>
#      </a>
#     </li>
#    </ul>
#   </div>
#  </div>
#  <div class="structItem-cell structItem-cell--meta" title="First message reaction score: 0">
#   <dl class="pairs pairs--justified">
#    <dt>
#     Replies
#    </dt>
#    <dd>
#     1
#    </dd>
#   </dl>
#   <dl class="pairs pairs--justified structItem-minor">
#    <dt>
#     Views
#    </dt>
#    <dd>
#     17
#    </dd>
#   </dl>
#  </div>
#  <div class="structItem-cell structItem-cell--latest">
#   <a href="/threads/how-did-you-get-your-ppp-loan-forgiven.432355/latest" rel="nofollow">
#    <time class="structItem-latestDate u-dt" data-date-string="Feb 25, 2021" data-time="1614263790" data-time-string="6:36 AM" datetime="2021-02-25T06:36:30-0800" dir="auto" title="Feb 25, 2021 at 6:36 AM">
#     7 minutes ago
#    </time>
#   </a>
#   <div class="structItem-minor">
#    <a class="username" data-user-id="125928" data-xf-init="member-tooltip" dir="auto" href="/members/father-of-unicorns.125928/" itemprop="name">
#     father of unicorns
#    </a>
#   </div>
#  </div>
#  <div class="structItem-cell structItem-cell--icon structItem-cell--iconEnd">
#   <div class="structItem-iconContainer">
#    <a class="avatar avatar--xxs" data-user-id="125928" data-xf-init="member-tooltip" href="/members/father-of-unicorns.125928/">
#     <img alt="father of unicorns" class="avatar-u125928-s" height="48" loading="lazy" src="https://www.uberpeople.net/data/avatars/s/125/125928.jpg?1550022874" width="48"/>
#    </a>
#   </div>
#  </div>
# </div>

# %% [markdown]
# ### Extracting row items
# The items we want from this row are...
# - Author
# - Thread-id > useful for ensuring no duplicates and for quickly locating threads later.
# - Title
# - Date
# - URL

# %% [markdown]
# #### Author

# %%
# Author is located inside the division acts as the container for our first item.
# it is known as an attribute of the division called data-author. 
# We can retrieve the content of a tag attrribute as if the tag were a dictionary.

author = first_item['data-author']
print(author)
# Out:
# akwunomy

# %% [markdown]
# #### Thread_id

# %%
# Unique IDs are not necesarily present in all websites, but this site happens to use them
# It's not necessarily clear straight away from the code exactly what counts as the id.
# making these decisions often requires you to look around the site and
# get a feel for its structure.

# In this case we can see the same number being used in the top level row division, and in the 
# url for the thread content. We could extract this from either division but here we'll take it
# from the row data, where the id is in the 'class' 

first_item['class']
# Out:
# ['structItem',
#  'structItem--thread',
#  'js-inlineModContainer',
#  'js-threadListItem-432355']

# %%
# class has multiple elements which beautifulsoup returns as a list,
# we need the last item in the list
id_item = first_item['class'][-1]
id_item
# Out:
# 'js-threadListItem-432355'

# %%
# the last item is a string and we just need everything after the '-'
# we split up the string on the '-'...
id_item.split('-')
# Out:
# ['js', 'threadListItem', '432355']

# %%
# grab the last item...
id_item.split('-')[-1]
# Out:
# '432355'

# %%
# and convert it into an integer rather than keep the string
thread_id = int(id_item.split('-')[-1])
thread_id
# Out:
# 432355

# %% [markdown]
# For the remainder of items we need to step into the sub-divisions of the element, the div's inside our div. The row is made up of multiple subsections containing the information we want so we will need to step from our top level division into the various subsections.

# %% [markdown]
# #### Title

# %%
# starting with our first_item we use .find to search within its subordinates to find the
# division containing the title.

title_div = first_item.find('div', class_='structItem-title')
title_div
# Out:
# <div class="structItem-title">
# <a class="" data-preview-url="/threads/how-did-you-get-your-ppp-loan-forgiven.432355/preview" data-tp-primary="on" data-xf-init="preview-tooltip" href="/threads/how-did-you-get-your-ppp-loan-forgiven.432355/">How did you get your PPP loan forgiven</a>
# </div>

# %%
# inside the title division is a url division which is always tagged with the <a> tag. 
# we can access this either with .find('a') or the convenience method of simply .a which
# selects the first child element that is an <a> tag.

title_div.a
# Out:
# <a class="" data-preview-url="/threads/how-did-you-get-your-ppp-loan-forgiven.432355/preview" data-tp-primary="on" data-xf-init="preview-tooltip" href="/threads/how-did-you-get-your-ppp-loan-forgiven.432355/">How did you get your PPP loan forgiven</a>

# %%
# .text allows us to just get the plain text <a> between the tags </a>
title = title_div.a.text
title
# Out:
# 'How did you get your PPP loan forgiven'

# %%
#.strip() is a string function that cleans up the ends removing white space and breaks.
# it is a good precautinary measure when gathering text from sites to ensure you aren't collecting
# erroneous whitespace.

title = title.strip()

# %% [markdown]
# #### Date

# %%
# if we inspect the date we can see it sits within a <time> tag within our row division
first_item.find('time')
# Out:
# <time class="u-dt" data-date-string="Feb 25, 2021" data-time="1614261190" data-time-string="5:53 AM" datetime="2021-02-25T05:53:10-0800" dir="auto" title="Feb 25, 2021 at 5:53 AM">50 minutes ago</time>

# %%
# Time is represented in a lot of different ways here, and Dates and times 
# are special types of object because they do not behave like normal numbers, 
# nor are they useful only as strings. The best thing to do is to save the string
# called 'datetime' and convert it from a string into a 'datetime' object.


date_string = first_item.find('time')['datetime']
print(date_string)
print(type(date_string))
# Out:
# 2021-02-25T05:53:10-0800
# <class 'str'>

# %%
# Currently this is a string, which will be problematic later if we want any analysis to
# understand it as time.

# We can convert it from a string to a datetime object using the datetime library

from datetime import datetime

# we need to instruct the datetime .strptime function what parts of the string pertain to 
# the different divisions of time. For this site our instruction looks like this...

date_format = '%Y-%m-%dT%H:%M:%S%z'
# the string instructs strptime which parts of the string 
# are time components and which parts are just string such as dashes and colons.
# See https://docs.python.org/2/library/datetime.html#strftime-and-strptime-behavior 
# for full documentation



# %Y - Year
# %m - Month
# %d - day
# %H - Hour
# %M - Minute
# %S - Second
# %z - Timezone offset from GMT in hours

date = datetime.strptime(date_string, date_format )
print(date)
print(type(date))
# Out:
# 2021-02-25 05:53:10-08:00
# <class 'datetime.datetime'>

# %% [markdown]
# #### URL

# %%
# to get to each thread, the user would click the title of the thread,
# meaning the url for the thread must be in the title division somewhere
title_div
# Out:
# <div class="structItem-title">
# <a class="" data-preview-url="/threads/how-did-you-get-your-ppp-loan-forgiven.432355/preview" data-tp-primary="on" data-xf-init="preview-tooltip" href="/threads/how-did-you-get-your-ppp-loan-forgiven.432355/">How did you get your PPP loan forgiven</a>
# </div>

# %%
# yes it is in the href attribute of the child <a>
title_div.a['href']
# Out:
# '/threads/how-did-you-get-your-ppp-loan-forgiven.432355/'

# %%
# But this is not a whole url, it's relative to the domain 'http://uberpeople.net'

# %%
# So let's put it all together
relative_url = title_div.a['href']
url = 'http://uberpeople.net' + relative_url
url
# Out:
# 'http://uberpeople.net/threads/how-did-you-get-your-ppp-loan-forgiven.432355/'

# %%
# However the safe way to do it, because URLS can go wonky sometimes is to use part of the standard library.
import urllib
url = urllib.parse.urljoin('http://uberpeople.net', relative_url)
# This has some verification features to make sure the URL makes sense.
print(url)
# Out:
# http://uberpeople.net/threads/how-did-you-get-your-ppp-loan-forgiven.432355/

# %% [markdown]
# ### Putting it all Together

# %%
def row_info_extractor(row): # We'll feed it the isolated html for a row and let it pull it apart.
    
    #author
    author = row['data-author']
    
    #id
    id_item = row['class'][-1]
    thread_id = int(id_item.split('-')[-1])
    
    #title
    title_div = row.find('div', class_='structItem-title')
    title = title_div.a.text.strip() # remember to .strip() off the useless spaces on the ends.
    
    #date
    date_format = '%Y-%m-%dT%H:%M:%S%z'
    date_string = row.find('time')['datetime']


    date = datetime.strptime(date_string, date_format)
    
    #replies
    replies = row.find('dl', class_='pairs pairs--justified').dd.text
    
    #views
    views = row.find('dl',class_='pairs pairs--justified structItem-minor').dd.text

    
    #url
    relative_url = title_div.a['href']
    # remember the url is only relative so it needs to be made full using urlib.parse.urljoin
    full_url = urllib.parse.urljoin('http://uberpeople.net',relative_url)
    
    # And now we spit out our final product - in this case we'll go for a list for Pandas use later.
    # We'll also re-order
    data_package = {'author':author,
                   'title':title,
                   'thread_id':thread_id,
                   'date':date,
                   'url':full_url}
    
    return data_package

# %%
# Let's try it out

soup = BeautifulSoup(response.text,'lxml')
threads_container = soup.find('div', class_="structItemContainer-group js-threadList")
threads = threads_container.find_all('div', {'class':'structItem--thread', 'data-author':True} )

first_item = threads[0]


row_info_extractor(first_item)
# Out:
# {'author': 'akwunomy',
#  'title': 'How did you get your PPP loan forgiven',
#  'thread_id': 432355,
#  'date': datetime.datetime(2021, 2, 25, 5, 53, 10, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))),
#  'url': 'http://uberpeople.net/threads/how-did-you-get-your-ppp-loan-forgiven.432355/'}

# %%
data = []
for row in threads:
    row_info = row_info_extractor(row)
    data.append(row_info)

# %%
import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#                  author                                              title  \
# 0              akwunomy             How did you get your PPP loan forgiven
# 1               ng4ever  As a Uber or Lyft driver or both do you ever t...
# 2         Dr. Saw Bones      I want gas prices at over 8 dollars a gallon!
